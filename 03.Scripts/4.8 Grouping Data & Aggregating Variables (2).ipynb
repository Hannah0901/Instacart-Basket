# %% [markdown]
# # Task4.8

# %% [markdown]
# Step 1

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating a path for this project
path=r'C:\online course\career\python data\202304'

# %%
# Importing data
df_orders_products_merged=pd.read_pickle(r'C:\online course\career\python data\202304\02.Data\Prepared data\orders_products_merged_new4.7.pkl')

# %%
df_orders_products_merged.head(3)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
#
#    order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# 0                  8             NaN         196                  1
# 1                  7            15.0         196                  1
# 2                 12            21.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices    price_range_loc  \
# 0          0         Soda        77              7     9.0  Mid-range product
# 1          1         Soda        77              7     9.0  Mid-range product
# 2          1         Soda        77              7     9.0  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly days        Average orders
# ...

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 18)

# %% [markdown]
# step 2 In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#Grouping data by 'department_id' and then aggregating to find mean of 'order_number'
df_orders_products_merged.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# step 3 Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# We may notice differences between the entire dataframe and a subset of the data. The entire dataset includes all the data, and the average calculated from it may be more representative than that of a subset.

# %% [markdown]
# Step4 Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# We make a new column called 'max_order', group by "user_id" calculate by order_number

# %%
df_orders_products_merged.head(12)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
#
#     order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# ...

# %%
# Creating a 'loyalty' flag
df_orders_products_merged.loc[df_orders_products_merged['max_order']>40,'loyalty_flag']='Loyal customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['max_order']<=40)&(df_orders_products_merged['max_order']>10),'loyalty_flag']='Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order']<10,'loyalty_flag']='New customer'

# %%
df_orders_products_merged['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         5470866
# NaN                   773124
# Name: loyalty_flag, dtype: int64

# %%
df_orders_products_merged[['user_id','loyalty_flag','order_number']].head(2)
# Out:
#    user_id loyalty_flag  order_number
# 0        1          NaN             1
# 1        1          NaN             2

# %% [markdown]
# Step5 The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Performing multiple aggregations ('min', 'max', 'mean', 'sum')
df_orders_products_merged.groupby('loyalty_flag').agg({'prices':['min','max','mean','sum']})
# Out:
#                  prices
#                     min      max       mean          sum
# loyalty_flag
# Loyal customer      1.0  99999.0  10.386336  106814042.2
# New customer        1.0  99999.0  13.208375   72261247.5
# Regular customer    1.0  99999.0  12.495717  198391693.2

# %% [markdown]
# There are some differences in the data.The mean purchase for "New customers"is the highest,while it is the lowest for "Loyal customers".However, the total purchase price for"Regular customers"is higher than the totals for the otjer two groups,which is due to the larger number of "Regular customers"compared to "New"and"Loyal"customers.

# %% [markdown]
# step 6 The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'prices' column to generate the average prices for each user.
df_orders_products_merged['avg_price'] = df_orders_products_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_orders_products_merged.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
#
#    order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# 0                  8             NaN         196                  1
# 1                  7            15.0         196                  1
# ...

# %% [markdown]
#  If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.” If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Creating a 'spending' flag
df_orders_products_merged.loc[df_orders_products_merged['avg_price']<10,'spending_flag']='Low spender'

# %%
# Creating a 'spending' flag
df_orders_products_merged.loc[df_orders_products_merged['avg_price']>=10,'spending_flag']='High spender'

# %%
df_orders_products_merged.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
#
#    order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# 0                  8             NaN         196                  1
# 1                  7            15.0         196                  1
# ...

# %%
df_orders_products_merged.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  Order Interval    product_id  add_to_cart_order  \
# count       3.240486e+07    3.032876e+07  3.240486e+07       3.240486e+07
# mean        1.342515e+01    1.110408e+01  2.559866e+04       8.352547e+00
# std         4.246380e+00    8.779064e+00  1.408400e+04       7.127071e+00
# ...

# %%
#Checking the count of 'spending_flag' values
df_orders_products_merged['spending_flag'].value_counts(dropna=False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
df_orders_products_merged['spending_flag'].value_counts(dropna=False).sum()
# Out:
# 32404859

# %%
# to check out wether some data missing
df_orders_products_merged.shape
# Out:
# (32404859, 22)

# %% [markdown]
# The sum of count of values of 'spending_flag' is equal to total number of rows

# %% [markdown]
# Step 7
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'days_since_prior_order' column to generate the median order frequency for each user.
df_orders_products_merged['median_freq'] = df_orders_products_merged.groupby(['user_id'])['Order Interval'].transform(np.median)

# %%
# create order_freq_flag
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
df_orders_products_merged.loc[df_orders_products_merged['median_freq']>20,'order_freq_flag']='Non-frequent customer'

# %%
#If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
df_orders_products_merged.loc[(df_orders_products_merged['median_freq']>10)&(df_orders_products_merged['median_freq']<=20),'order_freq_flag']='Regular customer'

# %%
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
df_orders_products_merged.loc[df_orders_products_merged['median_freq']<=10,'order_freq_flag']='Frequent customer'

# %%
df_orders_products_merged.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
#
#    order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# 0                  8             NaN         196                  1
# 1                  7            15.0         196                  1
# ...

# %%
#Checking the count of 'order_freq_flag' values
df_orders_products_merged['order_freq_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_freq_flag, dtype: int64

# %% [markdown]
# We could find that the number of Frequent customer is higher than Regular customer.It's mean we can put more advantage in Frequent customer and make than more Frequent to buy our product.

# %%
df_orders_products_merged['order_freq_flag'].value_counts(dropna=False).sum()
# Out:
# 32404859

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 24)

# %%
#drop the rows where at least one element is missing.
df_orders_products_merged.dropna()
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 10         2968173       15    prior            15                   1
# 11         1870022       15    prior            17                   2
# 12         1911383       15    prior            18                   2
# 13         2715276       15    prior            21                   1
# 14          487368       15    prior            22                   1
# ...            ...      ...      ...           ...                 ...
# 32404852   2329472   202557    prior            15                   6
# 32404853    694731   202557    prior            16                   1
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404857   2745165   203436    prior             2                   3
#
#           order_hour_of_day  Order Interval  product_id  add_to_cart_order  \
# ...

# %%
# create a new version with a different name
df_orders_products_merged_clean=df_orders_products_merged.dropna()

# %%
# check
df_orders_products_merged_clean['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         4455665
# Name: loyalty_flag, dtype: int64

# %%
df_orders_products_merged_clean['order_freq_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        20468777
# Regular customer          6333470
# Non-frequent customer     2830490
# Name: order_freq_flag, dtype: int64

# %%
df_orders_products_merged_clean.shape
# Out:
# (29632737, 24)

# %% [markdown]
# Step 9 exported data

# %%
df_orders_products_merged_clean.to_pickle(os.path.join(path,'02.Data','Prepared data','orders_products_merged_aggregated.pkl'))
